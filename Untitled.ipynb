# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dreyl2'

# %%
df = pd.read_csv("midterm_train.csv")

# %%
df
# Out:
#        Interest_Rate   Loan_ID  Borrower_ID Loan_Amount_Requested  \
# 0             11.89%     54734        80364              $25,000
# 1             10.71%     55742       114426               $7,000
# 2             16.99%     57167       137225              $25,000
# 3             13.57%     57416       139635              $10,800
# 4             19.05%     58524       149512               $7,200
# 5             14.26%     59006       154254               $3,000
# 6              7.88%     61390       182594               $4,000
# 7              9.88%     62102       191024               $3,200
# 8             11.14%     65426       232106               $4,000
# 9             12.21%     66431       243540               $2,525
# 10            13.47%     66749       246329              $10,625
# 11            13.24%     66964       247990               $7,500
# 12             8.59%     67503       252415              $10,000
# ...

# %%
df['Sub_Loan_Grade'].fillna("Missing", inplace=True)

# %%
dummies = pd.get_dummies(df['Sub_Loan_Grade'], prefix = 'Sub_Loan_Grade')
df = pd.concat([df, dummies], axis = 1)
df.drop(['Sub_Loan_Grade'], axis=1, inplace=True)

# %%
df.drop(['Loan_Grade'], axis=1, inplace=True)
df.drop(['Employer'], axis=1, inplace=True)
